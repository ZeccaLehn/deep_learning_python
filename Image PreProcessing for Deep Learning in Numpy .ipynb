# %%
import numpy as np

# %%
URL = "https://upload.wikimedia.org/wikipedia/en/a/a9/Example.jpg"

from PIL import Image
import requests
from io import BytesIO

response = requests.get(URL)
img = Image.open(BytesIO(response.content))
# img = Image.open(filepath) # From image on laptop

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x297 at 0x23B715D37B8>

# %%
img.size # (width,height) tuple

print(img.size)

data = np.asarray( img, dtype="int32" )

data[[0]][:,0]

print(data.shape)

# data.T
# help(np.reshape)
# Out:
# (275, 297)
# (297, 275, 3)

# %%
data.reshape(1, 297*275*3)
# Out:
# array([[155, 155, 155, ..., 134, 134, 134]])

# %%
# help(np.reshape)
